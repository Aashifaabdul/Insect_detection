# %%
ROOT_DIR = 'E:\Arul\internship\Propeller Technologies\Aashifa\yolov8\Red weevil classification.v4i.yolov8'

# %%
import torch

# Check if GPU is available
if torch.cuda.is_available():
    # If GPU is available, set the device to GPU
    device = torch.device("cuda")
    print("GPU is available!")
else:
    # If GPU is not available, set the device to CPU
    device = torch.device("cpu")
    print("GPU is not available, using CPU instead.")
# Out:
# GPU is available!

# %%
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# PyTorch version: 2.3.0+cu121
# CUDA available: True
# CUDA version: 12.1
# GPU device name: NVIDIA GeForce RTX 3060 Ti

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "E:\Arul\internship\Propeller Technologies\Aashifa\yolov8\Red weevil classification.v4i.yolov8\data.yaml"), epochs=25)
# Out:
# New https://pypi.org/project/ultralytics/8.2.70 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.22  Python-3.11.4 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# e:\Arul\internship\Propeller Technologies\Aashifa\yolov8\Red weevil classification.v4i.yolov8

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
ls "E:\Arul\internship\Propeller Technologies\Aashifa\yolov8\Red weevil classification.v4i.yolov8\\runs"
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 765F-8422
#
#  Directory of E:\Arul\internship\Propeller Technologies\Aashifa\yolov8\Red weevil classification.v4i.yolov8\runs
#
# 30-07-2024  21:46    <DIR>          .
# 30-07-2024  21:46    <DIR>          ..
# 30-07-2024  21:46    <DIR>          detect
#                0 File(s)              0 bytes
#                3 Dir(s)  244,185,677,824 bytes free

# %%
from ultralytics import YOLO

from IPython.display import display, Image
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_labels.jpg', width=600)
# Out:
# e:\Arul\internship\Propeller Technologies\Aashifa\yolov8\Red weevil classification.v4i.yolov8

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model="E:\Arul\internship\Propeller Technologies\Aashifa\yolov8\Red weevil classification.v4i.yolov8\\runs\detect\\train\weights\\best.pt" conf=0.25 source="E:\Arul\internship\Propeller Technologies\Aashifa\yolov8\Red weevil classification.v4i.yolov8\\red_palm_weevil-7.webp" save=True
# Out:
# e:\Arul\internship\Propeller Technologies\Aashifa\yolov8\Red weevil classification.v4i.yolov8
# Ultralytics YOLOv8.2.22 🚀 Python-3.11.4 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# YOLOv8n summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 E:\Arul\internship\Propeller Technologies\Aashifa\yolov8\Red weevil classification.v4i.yolov8\red_palm_weevil-7.webp: 480x640 1 Red-palm-weevil, 87.2ms
# Speed: 2.0ms preprocess, 87.2ms inference, 831.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
